# %% [markdown]
# # Intro
#
# See the [original project proposal](https://github.com/OpenMined/OpenMined/issues/423).
#
# # Installation
#
# As specified in https://github.com/udacity/RL-Quadcopter:
# * Robot Operating System (ROS)
# * Drone Simulator
# * Clone and build the RL-Quadcopter project into your `~/catkin_ws/src/` directory
#
# This demo was tested in a native ROS installation on Ubuntu 16.04.

# %% [markdown]
# ## Copy Files
#
# Copy this demo's Python source code to your ROS directory:

# %%
# %%bash
#
# cp -r {launch/,src/} ~/catkin_ws/src/RL-Quadcopter/quad_controller_rl/

# %% [markdown]
# # Run Simulator

# %% [markdown]
# In a separate terminal, switch to your pre-defined Python environment and run the bash script included in the same directory as this Jupyter notebook:
#
# ```bash
#
# source activate root  # Example Anaconda base environment, but you may be using a different Python env manager
# ./run.sh
#
# ```

# %% [markdown]
# # Plot of Episode Rewards
#
# As the agent learns, it'll attain more rewards until it gets the max after around episode 80 or so. For definitions of the terms "episode" and "reward", refer to the [classic reinforcement learning textbook](http://incompleteideas.net/book/the-book-2nd.html).

# %%
% matplotlib inline

import pandas as pd

df_stats = pd.read_csv("~/catkin_ws/src/RL-Quadcopter/quad_controller_rl/out/stats_2018-02-17_15-26-55.csv")
df_stats[['total_reward']].plot(title="Episode Rewards")
