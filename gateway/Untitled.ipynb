# %%
import torch as th
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import binascii
import syft as sy

# import sys
# sys.path.insert(0, <path to dirFoo>)

# import os
# import sys
# sys.path.append(os.getcwd())
from app.main.processes import processes


# import os.path, sys
# sys.path.append(os.path.dirname(__file__))



from syft.serde.serde import serialize, deserialize



# async def test_fl_process(self):
#         """ 1 - Host Federated Training """
#         # Plan Functions
@sy.func2plan(args_shape=[(1,), (1,), (1,)])
def foo_1(x, y, z):
    a = x + x
    b = x + z
    c = y + z
    return c, b, a

@sy.func2plan(args_shape=[(1,), (1,), (1,)])
def foo_2(x, y, z):
    a = x + x
    b = x + z
    return b, a

@sy.func2plan(args_shape=[(1,), (1,)])
def avg_plan(x, y):
    result = x + y / 2
    return result

# Plan Model
class Net(sy.Plan):
    def __init__(self):
        super(Net, self).__init__(id="my-model")
        self.fc1 = nn.Linear(2, 3)
        self.fc2 = nn.Linear(3, 2)
        self.fc3 = nn.Linear(2, 1)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        x = self.fc3(x)
        return F.log_softmax(x, dim=0)

model = Net()
model.build(th.tensor([1.0, 2]))

# Serialize plans / protocols and model
serialized_plan_method_1 = binascii.hexlify(serialize(foo_1)).decode()
#         serialized_plan_method_2 = binascii.hexlify(serialize(foo_2)).decode()
serialized_avg_plan = binascii.hexlify(serialize(avg_plan)).decode()
serialized_plan_model = binascii.hexlify(serialize(model)).decode()

# As mentioned at federated learning roadmap.
# We're supposed to set up client / server configs
client_config = {
    "name": "my-federated-model",
    "version": "0.1.0",
    "batch_size": 32,
    "lr": 0.01,
    "optimizer": "SGD",
}

server_config = {
    "max_workers": 100,
    "pool_selection": "random",  # or "iterate"
    "num_cycles": 5,
    "do_not_reuse_workers_until_cycle": 4,
    "cycle_length": 8 * 60 * 60,  # 8 hours
    "minimum_upload_speed": 2,  # 2 mbps
    "minimum_download_speed": 4,  # 4 mbps
}

# "federated/host-training" request body
host_training_message = {
    "type": "federated/host-training",
    "data": {
        "model": serialized_plan_model,
        "plans": {
            "foo_1": serialized_plan_method_1,
#             "foo_2": serialized_plan_method_2,
        },
        "protocols": {"protocol_1": "serialized_protocol_mockup"},
        "averaging_plan": serialized_avg_plan,
        "client_config": client_config,
        "server_config": server_config,
    },
}

# Send host_training message
#         response = await send_ws_message(host_training_message)
#         self.assertEqual(response, {"status": "success"})


processes.create_process(serialized_plan_model, serialized_plan_method_1, client_config, server_config, serialized_avg_plan)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sqlalchemy/util/_collections.py in __call__(self)
#    1029         try:
# -> 1030             return self.registry[key]
#    1031         except KeyError:
#
# KeyError: <greenlet.greenlet object at 0x7fd150898890>
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-4474fb668c2d> in <module>
#     109
#     110
# --> 111 processes.create_process(serialized_plan_model, serialized_plan_method_1, client_config, server_config, serialized_avg_plan)
#     112
#     113
#
# ~/Desktop/dev_env/openMined/PyGrid/gateway/app/main/processes/controller.py in create_process(self, model, client_plans, client_config, server_config, server_averaging_plan, client_protocols)
#     238
#     239         # Register a new FL Process
# --> 240         fl_process = self._processes.register()
#     241
#     242         _model = self._models.query(id=model.id)
#
# ~/Desktop/dev_env/openMined/PyGrid/gateway/app/main/storage/warehouse.py in register(self, **kwargs)
#      14         """
#      15         _obj = self._schema(**kwargs)
# ---> 16         db.session.add(_obj)
#      17         db.session.commit()
#      18
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sqlalchemy/orm/scoping.py in do(self, *args, **kwargs)
#     160 def instrument(name):
#     161     def do(self, *args, **kwargs):
# --> 162         return getattr(self.registry(), name)(*args, **kwargs)
#     163
#     164     return do
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sqlalchemy/util/_collections.py in __call__(self)
#    1030             return self.registry[key]
#    1031         except KeyError:
# -> 1032             return self.registry.setdefault(key, self.createfunc())
#    1033
#    1034     def has(self):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sqlalchemy/orm/session.py in __call__(self, **local_kw)
#    3232             else:
#    3233                 local_kw.setdefault(k, v)
# -> 3234         return self.class_(**local_kw)
#    3235
#    3236     def configure(self, **new_kw):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/flask_sqlalchemy/__init__.py in __init__(self, db, autocommit, autoflush, **options)
#     134     def __init__(self, db, autocommit=False, autoflush=True, **options):
#     135         #: The application that this session belongs to.
# --> 136         self.app = app = db.get_app()
#     137         track_modifications = app.config['SQLALCHEMY_TRACK_MODIFICATIONS']
#     138         bind = options.pop('bind', None) or db.engine
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/flask_sqlalchemy/__init__.py in get_app(self, reference_app)
#     980
#     981         raise RuntimeError(
# --> 982             'No application found. Either work inside a view function or push'
#     983             ' an application context. See'
#     984             ' http://flask-sqlalchemy.pocoo.org/contexts/.'
#
# RuntimeError: No application found. Either work inside a view function or push an application context. See http://flask-sqlalchemy.pocoo.org/contexts/.

# %%
pwd
# Out:
# '/Users/mshang/Desktop/dev_env/openMined/PyGrid/gateway'
